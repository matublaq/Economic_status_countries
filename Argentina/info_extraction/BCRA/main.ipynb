# %%
import pandas as pd
import numpy as np
import os
import requests
import json

# %%
url1 = "https://api.bcra.gob.ar/estadisticas/v3.0/monetarias"

response1 = requests.get(url1, verify=False)

rta1 = response1.json()

##################################
url2 = "https://api.bcra.gob.ar/estadisticascambiarias/v1.0/Maestros/Divisas"

reponse2 = requests.get(url2, verify=False)

rta2 = reponse2.json()

##################################
url3 = "https://api.bcra.gob.ar/estadisticascambiarias/v1.0/Cotizaciones" #?fecha=2025-04-01

response3 = requests.get(url3, verify=False)

rta3 = response3.json()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
rta3
# Out:
# {'status': 200,
#  'results': {'fecha': '2025-04-30',
#   'detalle': [{'codigoMoneda': 'ARS',
#     'descripcion': 'PESO',
#     'tipoPase': 0.000855,
#     'tipoCotizacion': 0.0},
#    {'codigoMoneda': 'AUD',
#     'descripcion': 'DOLAR AUSTRALIA',
#     'tipoPase': 0.6396,
#     'tipoCotizacion': 748.332},
#    {'codigoMoneda': 'AWG',
#     'descripcion': 'FLORIN (ANTILLAS HOLANDESAS)',
#     'tipoPase': 0.558659,
#     'tipoCotizacion': 653.631285},
#    {'codigoMoneda': 'BOB',
#     'descripcion': 'BOLIVIANOS',
#     'tipoPase': 0.145191,
#     'tipoCotizacion': 169.872958},
#    {'codigoMoneda': 'BRL',
#     'descripcion': 'REAL',
#     'tipoPase': 0.176137,
#     'tipoCotizacion': 206.080248},
#    {'codigoMoneda': 'CAD',
#     'descripcion': 'DOLAR CANADIEN.',
#     'tipoPase': 0.724743,
#     'tipoCotizacion': 847.948978},
#    {'codigoMoneda': 'CHF',
#     'descripcion': 'FRANCO SUIZO',
#     'tipoPase': 1.215214,
#     'tipoCotizacion': 1421.800948},
# ...
